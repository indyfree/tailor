# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import os

my_path = os.path.abspath(os.path.dirname("__file__"))
path_iris = os.path.join(my_path, '..', "data/test/iris.csv")
path_iris = os.path.normpath(path_iris)
print(path_iris)
df_iris = pd.read_csv(path_iris)
# Out:
# /home/chris/github-projects/dsip1/data/test/iris.csv

# %%
print(df_iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
plt.scatter(df_iris['species'], df_iris['sepal_length'])
#referencing certain columns in DataFrame is only possible with the column label

# %%
plt.scatter(x=df_iris['petal_length'], y=df_iris['petal_width'])

# %%
#ugly af
color_species = ['red' if s == 'setosa' else ('blue' if s == 'versicolor' else 'green') for s in df_iris['species']]
print(color_species)
# Out:
# ['red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'gre
# ...

# %%
#easier on the eye
def color_for_species(species):
    if species == 'setosa':
        return 'red'
    elif species == 'versicolor':
        return 'blue'
    else:
        return 'green'
    
color_species = [color_for_species(s) for s in df_iris['species']]
print(color_species)
# Out:
# ['red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'gre
# ...

# %%
#using dictionary
def color_for_species_dict(species):
    return {
        'setosa':'red',
        'versicolor': 'blue',
        'virginica' : 'green'
    }.get(species, 'black') #black is default if not found

color_species = [color_for_species_dict(s) for s in df_iris['species']]
print(color_species)
# Out:
# ['red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'gre
# ...

# %%
# using pyplot plotting
plt.scatter(x=df_iris['petal_length'], y=df_iris['petal_width'], c=color_species)

# %%
# using DataFrame plotting
df_iris.plot(kind='scatter', x='petal_length', y='petal_width', c=color_species)

# %%
df_iris.plot(kind='line', x='petal_length', y='petal_width')

# %%
df_iris.plot(kind='bar', x='petal_length', y='petal_width')

# %%
df_iris.plot(kind='barh', x='petal_length', y='petal_width')

# %%
df_iris.plot(kind='hist', x='petal_length', y='petal_width')

# %%
df_iris.plot(kind='box', x='petal_length', y='petal_width')

# %%
df_iris.plot(kind='density', x='petal_length', y='petal_width')

# %%
df_iris.plot(kind='area', x='petal_length', y='petal_width')

# %%
df_iris.plot(kind='hexbin', x='petal_length', y='petal_width', gridsize=10)

# %%
# set() to get distinct values
# size() to get the count
# T to transform to correct rotation
df_iris_pie = pd.DataFrame([set(df_iris['species']), df_iris.groupby('species').size()]).T
print(df_iris_pie)
print()
# change column names
df_iris_pie.columns = ['species', 'amount']
print(df_iris_pie)
df_iris_pie.plot(kind='pie', y='amount', labels=df_iris_pie['species'], legend=False, startangle=90)
# Out:
#             0   1
# 0  versicolor  50
# 1      setosa  50
# 2   virginica  50
#
#       species amount
# 0  versicolor     50
# 1      setosa     50
# 2   virginica     50
